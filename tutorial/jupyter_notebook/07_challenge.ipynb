# %% [markdown]
# <p> <center> <a href="../start_here.ipynb">Home Page</a> </center> </p>
#
# <div>
#     <span style="float: left; width: 33%; text-align: left;"><a href="06_nemo_agent_toolkit.ipynb">Previous Notebook</a></span>
#     <span style="float: left; width: 34%; text-align: center;">
#         <a href="01_opencode_intro.ipynb">1</a>
#         <a href="02_inference_endpoint.ipynb">2</a>
#         <a href="03_introduction_mcp.ipynb">3</a>
#         <a href="04_low_level_mcp.ipynb">4</a>
#         <a href="05_langraph_agent.ipynb">5</a>
#         <a href="06_nemo_agent_toolkit.ipynb">6</a>
#         <a >7</a>
#         <a href="bonus_challenge/08_bonus_challenge.ipynb">8</a>
#     </span>
#     <span style="float: left; width: 33%; text-align: right;"><a href="bonus_challenge/08_bonus_challenge.ipynb">Next Notebook</a></span>
# </div>

# %% [markdown]
# # Challenge Overview
# ---

# %% [markdown]
# Modern e-commerce support is a strong use case for agentic systems. Customers ask broad product questions, request help with past purchases, and expect fast, accurate routing when they need refunds or other account support. This challenge brings those needs together into one practical workflow so students can apply the course concepts in a realistic customer support setting.
#
# In this course challenge, you will extend the provided music store support system into an intelligent e-commerce agent that understands customer needs and routes each request to the right workflow. The agent should answer general customer inquiries, process refund requests, and identify customer intent so it can deliver the appropriate support experience.
#
# From this challenge, participants should be able to
# 1) create MCP servers utilising the low level python sdk
# 2) package MCP servers into a format reusable by any MCP client
# 3) implement agent skills based on progressive disclosure
# 4) craft workflows with human-in-the-loop through langgraph
# 5) utilise Nvidia NIMs as the LLM backbone in agentic workflows

# %% [markdown]
# <left>
# <p>The original workflow is as follows <a href="https://docs.smith.langchain.com/evaluation/tutorials/agents">langchain agent evaluation</a>
# </p>
# <img src="./images/orig_workflow.png" width="500"/>
# </left>

# %% [markdown]
# The workflow has 3 main parts,
# 1) the intent classifier,
# 2) the question answering (qna) agent for handling general customer inquiries and
# 3) the refund agent for processing refund requests.

# %% [markdown]
# To complete the challenge, you will
# 1) allow human intervention if intent is unknown
# 2) incorporate the use of MCP protocol in the refund agent so it can access invoice data
# 3) utilize agent skills in the qna agent for grounded customer support responses

# %% [markdown]
# <left>
# <p>Resulting workflow</p>
# <img src="images/new_workflow.jpeg" width="500"/>
# </left>

# %% [markdown]
# The refund agent connects to the invoice MCP server to answer customer queries related to invoices and refunds
#
# The invoice MCP server provides access to the below tools
# 1) invoice search
# 2) invoice refund

# %% [markdown]
# The qna agent is equipped with agent skills to generate SQL queries that can then be executed on the Chinook DB to retrieve information on artists, albums and tracks for customer-facing answers.

# %% [markdown]
# <left>
# <p>Components of the invoice/qna agents</p>
# <img src="images/final_workflow.jpeg" width="1000"/>
# </left>

# %% [markdown]
# ## Getting Started
#
# All challenge materials live under `challenge/`. The easiest way to approach the work is to complete the assignments in order, since each stage builds on the previous one.

# %% [markdown]
# Start with these editable files:
#
# 1. [mcp-servers/invoice/src/mcp_server_invoice/server_http.py](../../challenge/mcp-servers/invoice/src/mcp_server_invoice/server_http.py) for the Invoice MCP server
# 2. [qna_agent/skills/music-store-assistant/SKILL.md](../../challenge/qna_agent/skills/music-store-assistant/SKILL.md) for the QNA agent skill
# 3. [llm_workflow/main.py](../../challenge/llm_workflow/main.py) and [llm_workflow/mcp_http_client.py](../../challenge/llm_workflow/mcp_http_client.py) for the end-to-end LLM workflow
# 4. [nemo_agent_toolkit/workflow.yaml](../../challenge/nemo_agent_toolkit/workflow.yaml) for the NeMo Agent Toolkit configuration
#
# Each challenge folder also includes a `README.md` with setup details, and the matching test folders show how to validate your solution locally before submission.

# %% [markdown]
# ---

# %% [markdown]
# ## Assignment
#
# 1. Each of the challenge folders has a `pyproject.toml` file that lists all dependencies. You are limited to only using these dependencies.
# 2. Do not change any of the file/folder names
# 3. Do not change any of the imports, environment variables, class/function headers, model ids in all python files.

# %% [markdown]
# ### Assignment 1 - Invoice MCP Server

# %% [markdown]
# This assignment is scored out of ***5 points***.

# %% [markdown]
# The following folders/files for the invoice mcp-server have been provided to you.

# %% [markdown]
# ```bash
# invoice
# ├── data
# │   └── chinook.db
# ├── pyproject.toml
# ├── README.md
# ├── src
# │   └── mcp_server_invoice
# │       ├── __init__.py
# │       └── server_http.py
# └── uv.lock
# ```

# %% [markdown]
# The task is to complete the code in the following python files.
# - [invoice mcp server](../../challenge/mcp-servers/invoice/src/mcp_server_invoice/server_http.py)

# %% [markdown]
# #### Testing your solution

# %% [markdown]
# You can use the following to test your solution locally before submission. The test cases are minimal and you should add in more on your own.
# - [Test instruction](../../challenge/mcp-server-invoice-test/README.md)

# %% [markdown]
# ---

# %% [markdown]
# ### Assignment 2 - QNA agent

# %% [markdown]
# This assignment is scored out of ***2 points***.

# %% [markdown]
# The following folders/files for the qna agent have been provided to you.

# %% [markdown]
# ```bash
# qna_agent
# ├── main.py
# ├── pyproject.toml
# ├── README.md
# ├── skills
# │   └── music-store-assistant
# │       └── SKILL.md
# ├── skills_ref
# │   ├── errors.py
# │   ├── models.py
# │   ├── parser.py
# │   ├── prompt.py
# │   ├── utils.py
# │   └── validator.py
# └── uv.lock
# ```

# %% [markdown]
# The task is to complete the SKILL.md file for the qna agent
# - [SKILL.md](../../challenge/qna_agent/skills/music-store-assistant/SKILL.md)

# %% [markdown]
# You can use the following to test your solution locally before submission. The test cases are minimal and you should add in more on your own.
# - [Test instruction](../../challenge/qna-agent-test/README.md)

# %% [markdown]
# ---

# %% [markdown]
# ### Assignment 3 - LLM Workflow

# %% [markdown]
# *Ensure assignments 1 and 2 are complete before starting on this assignment*

# %% [markdown]
# This assignment is scored out of ***4 points***.

# %% [markdown]
# The following folders/files for the llm workflow have been provided to you.

# %% [markdown]
# ```bash
# llm_workflow
# ├── __init__.py
# ├── chinook.db
# ├── main.py
# ├── mcp_http_client.py
# ├── pyproject.toml
# ├── README.md
# └── uv.lock
# ```

# %% [markdown]
# The task is to complete the code in the following python files.
#
# - [llm_workflow/main.py](../../challenge/llm_workflow/main.py)
# - [llm_workflow/mcp_http_client.py](../../challenge/llm_workflow/mcp_http_client.py)

# %% [markdown]
# #### Testing your solution

# %% [markdown]
# You can use the following to test your solution locally before submission. The test cases are minimal and you should add in more on your own.
# - [Test instruction](../../challenge/llm-workflow-test/README.md)

# %% [markdown]
# ---

# %% [markdown]
# ### Assignment 4 - NeMo Agent Toolkit

# %% [markdown]
# *Ensure assignments 1, 2 and 3 are complete before starting on this assignment*

# %% [markdown]
# This assignment is scored out of ***5 points***.

# %% [markdown]
# In this assignment, you will create a `workflow.yaml` configuration for the [NeMo Agent Toolkit (NAT)](https://docs.nvidia.com/nemo/agent-toolkit/latest/index.html) that connects to the invoice MCP server and answers queries about invoices in the Chinook database.
#
# Your workflow must define:
# 1. An **MCP client** function group that connects to the invoice MCP server
# 2. An **LLM** backed by an NVIDIA NIM endpoint
# 3. A **ReAct agent** workflow that uses the MCP tools and LLM to answer invoice-related questions
#
# The evaluation runs your `workflow.yaml` against 5 test questions. Each question is scored 0 or 1.

# %% [markdown]
# The following folders/files for the NeMo Agent Toolkit challenge have been provided to you.

# %% [markdown]
# ```bash
# nemo_agent_toolkit
# ├── README.md
# └── workflow.yaml
# ```

# %% [markdown]
# The task is to complete the workflow configuration in the following file.
# - [nemo_agent_toolkit/workflow.yaml](../../challenge/nemo_agent_toolkit/workflow.yaml)

# %% [markdown]
# #### Testing your solution

# %% [markdown]
# You can test your workflow locally by starting the invoice MCP server and running:
#
# ```bash
# nat run --config_file workflow.yaml --input "<question>"
# ```

# %% [markdown]
# ---

# %% [markdown]
# ## Submission

# %% [markdown]
# 1. To submit, Create [submission.zip](../../challenge/create-zip.sh) by running the following script

# %% [markdown]
# ```bash
# ./create-zip.sh
# ```

# %% [markdown]
# `submission.zip` contains only the required editable python files. Folder structure of zip archive as follows.

# %% [markdown]
# ```bash
# submission
# ├── llm-workflow
# │   ├── main.py
# │   └── mcp_http_client.py
# ├── mcp-servers
# │   └── invoice
# │       └── server_http.py
# ├── nemo-agent-toolkit
# │   └── workflow.yaml
# └── qna_agent
#     └── SKILL.md
# ```

# %% [markdown]
# 2. upload the zip archive to submit your solution.

# %% [markdown]
# ---
#
# ## Licensing

# %% [markdown]
# Copyright © 2026 OpenACC-Standard.org. This material is released by OpenACC-Standard.org, in collaboration with NVIDIA Corporation, under the Creative Commons Attribution 4.0 International (CC BY 4.0). These materials include references to hardware and software developed by other entities; all applicable licensing and copyrights apply.

# %% [markdown]
# <p> <center> <a href="../start_here.ipynb">Home Page</a> </center> </p>
#
# <div>
#     <span style="float: left; width: 33%; text-align: left;"><a href="06_nemo_agent_toolkit.ipynb">Previous Notebook</a></span>
#     <span style="float: left; width: 34%; text-align: center;">
#         <a href="01_opencode_intro.ipynb">1</a>
#         <a href="02_inference_endpoint.ipynb">2</a>
#         <a href="03_introduction_mcp.ipynb">3</a>
#         <a href="04_low_level_mcp.ipynb">4</a>
#         <a href="05_langraph_agent.ipynb">5</a>
#         <a href="06_nemo_agent_toolkit.ipynb">6</a>
#         <a >7</a>
#         <a href="bonus_challenge/08_bonus_challenge.ipynb">8</a>
#     </span>
#     <span style="float: left; width: 33%; text-align: right;"><a href="bonus_challenge/08_bonus_challenge.ipynb">Next Notebook</a></span>
# </div>
