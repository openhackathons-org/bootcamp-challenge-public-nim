# %% [markdown]
# <p> <center> <a href="../start_here.ipynb">Home Page</a> </center> </p>
#
# <div>
#     <span style="float: left; width: 33%; text-align: left;"><a href="01_Inference_endpoint.ipynb">Previous Notebook</a></span>
#     <span style="float: left; width: 34%; text-align: center;">
#         <a href="01_Inference_endpoint.ipynb">1</a>
#         <a >2</a>
#         <a href="03_introduction_mcp.ipynb">3</a>
#         <a href="04_low_level_mcp.ipynb">4</a>
#         <a href="05_langraph_agent.ipynb">5</a>
#         <a href="06_nemo_agent_toolkit.ipynb">6</a>
#         <a href="07_challenge.ipynb">7</a>
#         <a href="bonus_challenge/08_bonus_challenge.ipynb">8</a>
#     </span>
#     <span style="float: left; width: 33%; text-align: right;"><a href="03_introduction_mcp.ipynb">Next Notebook</a></span>
# </div>

# %% [markdown]
# ## Learning Objectives

# %% [markdown]
# - Setup Opencode with Nemotron 3 Nano as the coding assistant

# %% [markdown]
# Configure the local endpoint set up in [01_inference_endpoint](./01_inference_endpoint.ipynb)

# %%
# %%bash
# cat > ../../opencode.json <<EOF
# {
#   "\$schema": "https://opencode.ai/config.json",
#   "provider": {
#     "lm-studio": {
#       "npm": "@ai-sdk/openai-compatible",
#       "name": "Local NIM",
#       "options": {
#         "baseURL": "${INF_URL}"
#       },
#       "models": {
#         "nvidia/nemotron-3-nano": {
#           "name": "nemo-3-nano"
#         }
#       }
#     }
#   }
# }
# EOF

# %% [markdown]
# Open a new terminal in vscode server by expanding the hamburger menu (3 line menu icon at top left) -> Terminal -> New Terminal Window
#
# <div style="text-align: center;">
#   <img src="images/vscode-new-terminal.png" style="width: 900px; height: auto;">
# </div>

# %% [markdown]
# In the new terminal window, input `opencode` and press enter. This will get you into the opencode session. If `opencode` is not installed, install it using `curl -fsSL https://opencode.ai/install | bash`.
#
# <div style="text-align: center;">
#   <img src="images/opencode.png" style="width: 900px; height: auto;">
# </div>

# %% [markdown]
# Input `/models` and select `nemo-3-nano`. You can also choose any other model available in the catalog.

# %% [markdown]
# Opencode is now setup. You can use this to ask any question on the tutorials or assist you in the challenges.
#
# Example prompt: `Explain the code in challenge/mcp-servers/invoice/src/mcp_server_invoice/server_http.py`
#
# <div style="text-align: center;">
#   <img src="images/opencode-example.png" style="width: 900px; height: auto;">
# </div>

# %% [markdown]
# <p> <center> <a href="../start_here.ipynb">Home Page</a> </center> </p>
#
# <div>
#     <span style="float: left; width: 33%; text-align: left;"><a href="01_Inference_endpoint.ipynb">Previous Notebook</a></span>
#     <span style="float: left; width: 34%; text-align: center;">
#         <a href="01_Inference_endpoint.ipynb">1</a>
#         <a >2</a>
#         <a href="03_introduction_mcp.ipynb">3</a>
#         <a href="04_low_level_mcp.ipynb">4</a>
#         <a href="05_langraph_agent.ipynb">5</a>
#         <a href="06_nemo_agent_toolkit.ipynb">6</a>
#         <a href="07_challenge.ipynb">7</a>
#         <a href="bonus_challenge/08_bonus_challenge.ipynb">8</a>
#     </span>
#     <span style="float: left; width: 33%; text-align: right;"><a href="03_introduction_mcp.ipynb">Next Notebook</a></span>
# </div>
